# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv(r"E:\2022-2023 hk1\PTTK\CK\code\1-12-2017 1-12-2022\MSN Historical Data.csv")
df
# Out:
#             Date     Price      Open      High      Low       Vol.  Change %
# 0      12/1/2017   68500.0   67000.0   69400.0  66500.0   725370.0      0.02
# 1      12/4/2017   69000.0   70000.0   70000.0  68800.0  1190000.0      0.01
# 2      12/5/2017   68900.0   69000.0   70100.0  68600.0   777070.0      0.00
# 3      12/6/2017   67700.0   68900.0   69000.0  66000.0  1080000.0     -0.02
# 4      12/7/2017   69000.0   68600.0   69800.0  67300.0  1560000.0      0.02
# ...          ...       ...       ...       ...      ...        ...       ...
# 1244  11/25/2022   94000.0   90000.0   94500.0  90000.0   923100.0      0.06
# 1245  11/28/2022   97200.0   94000.0   97200.0  93500.0  2130000.0      0.03
# 1246  11/29/2022   99000.0   97200.0   99000.0  95500.0  2170000.0      0.02
# 1247  11/30/2022  102000.0   99500.0  102000.0  92900.0  1500000.0      0.03
# 1248   12/1/2022   99000.0  102000.0  102000.0  99000.0  1540000.0     -0.03
#
# [1249 rows x 7 columns]

# %%
df['Date']=pd.to_datetime(df.Date,format='%m/%d/%Y')
df=df.set_index(pd.DatetimeIndex(df['Date'].values))

# %%
plt.figure(figsize=(20,10))
plt.plot(df['Price'])
plt.show()

# %%
df.index = df.Date
df = pd.DataFrame(df, columns=['Price'])

# %%
import math
data = df.values
t = math.ceil(len(df)* 0.8)
train_data = data[:t]
test_data = data[t:]

# %%
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)
sc_train
# Out:
# array([[0.27865166],
#        [0.28353977],
#        [0.28256215],
#        ...,
#        [0.57682644],
#        [0.60615511],
#        [0.57682644]])

# %%
x_train=[]
y_train=[]
for i in range(60, len(train_data)):
    x_train.append(sc_train[i-60:i, 0])
    y_train.append(sc_train[i, 0])
    
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

print('x_train shape == {}.'.format(x_train.shape))
print('y_train shape == {}.'.format(y_train.shape))
# Out:
# x_train shape == (940, 60, 1).
# y_train shape == (940, 1).

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2
import tensorflow as tf

learning_rate = 0.0001
hidden_unit = 64
batch_size = 32
epoch = 100
model = Sequential()
model.add(LSTM(units=hidden_unit, return_sequences=True, input_shape =(x_train.shape[1],1), activation="relu"))
model.add(Dropout(0.2))
model.add(LSTM(units=hidden_unit, return_sequences=True,activation="relu"))
model.add(Dropout(0.2))
model.add(LSTM(units=hidden_unit, return_sequences=False,activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),loss='mean_squared_error')
pred = model.fit(x_train, y_train ,batch_size=batch_size, epochs=epoch)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 12s 80ms/step - loss: 0.1643
# Epoch 2/100
# 30/30 [==============================] - 2s 75ms/step - loss: 0.1162
# Epoch 3/100
# 30/30 [==============================] - 2s 81ms/step - loss: 0.0391
# Epoch 4/100
# 30/30 [==============================] - 2s 80ms/step - loss: 0.0103
# Epoch 5/100
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0083
# Epoch 6/100
# 30/30 [==============================] - 2s 79ms/step - loss: 0.0069
# Epoch 7/100
# 30/30 [==============================] - 3s 87ms/step - loss: 0.0061
# Epoch 8/100
# 30/30 [==============================] - 2s 73ms/step - loss: 0.0065
# Epoch 9/100
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0064
# Epoch 10/100
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0057
# Epoch 11/100
# 30/30 [==============================] - 2s 76ms/step - loss: 0.0055
# Epoch 12/100
# 30/30 [==============================] - 2s 74ms/step - loss: 0.0055
# Epoch 13/100
# 30/30 [==============================] - 2s 77ms/step - loss: 0.0055
# Epoch 14/100
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0054
# Epoch 15/100
# 30/30 [==============================] - 2s 73ms/step - loss: 0.0051
# Epoch 16/100
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0053
# Epoch 17/100
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0050
# Epoch 18/100
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0054
# Epoch 19/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0053
# Epoch 20/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0045
# Epoch 21/100
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0053
# Epoch 22/100
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0046
# Epoch 23/100
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0047
# Epoch 24/100
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0045
# Epoch 25/100
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0047
# Epoch 26/100
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0045
# Epoch 27/100
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0044
# Epoch 28/100
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0043
# Epoch 29/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0046
# Epoch 30/100
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0042
# Epoch 31/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0042
# Epoch 32/100
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0042
# Epoch 33/100
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0040
# Epoch 34/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0041
# Epoch 35/100
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0045
# Epoch 36/100
# 30/30 [==============================] - 2s 74ms/step - loss: 0.0040
# Epoch 37/100
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0040
# Epoch 38/100
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0043
# Epoch 39/100
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0043
# Epoch 40/100
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0040
# Epoch 41/100
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0041
# Epoch 42/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0039
# Epoch 43/100
# 30/30 [==============================] - 2s 73ms/step - loss: 0.0040
# Epoch 44/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0039
# Epoch 45/100
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0040
# Epoch 46/100
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0040
# Epoch 47/100
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0040
# Epoch 48/100
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0039
# Epoch 49/100
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0037
# Epoch 50/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0037
# Epoch 51/100
# 30/30 [==============================] - 2s 74ms/step - loss: 0.0034
# Epoch 52/100
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0036
# Epoch 53/100
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0039
# Epoch 54/100
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0036
# Epoch 55/100
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0037
# Epoch 56/100
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0037
# Epoch 57/100
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0033
# Epoch 58/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0038
# Epoch 59/100
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0035
# Epoch 60/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0040
# Epoch 61/100
# 30/30 [==============================] - 2s 76ms/step - loss: 0.0033
# Epoch 62/100
# 30/30 [==============================] - 3s 84ms/step - loss: 0.0034
# Epoch 63/100
# 30/30 [==============================] - 2s 76ms/step - loss: 0.0036
# Epoch 64/100
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0036
# Epoch 65/100
# 30/30 [==============================] - 2s 77ms/step - loss: 0.0038
# Epoch 66/100
# 30/30 [==============================] - 2s 79ms/step - loss: 0.0035
# Epoch 67/100
# 30/30 [==============================] - 2s 77ms/step - loss: 0.0037
# Epoch 68/100
# 30/30 [==============================] - 2s 77ms/step - loss: 0.0035
# Epoch 69/100
# 30/30 [==============================] - 2s 78ms/step - loss: 0.0034
# Epoch 70/100
# 30/30 [==============================] - 2s 78ms/step - loss: 0.0032
# Epoch 71/100
# 30/30 [==============================] - 3s 88ms/step - loss: 0.0035
# Epoch 72/100
# 30/30 [==============================] - 2s 82ms/step - loss: 0.0035
# Epoch 73/100
# 30/30 [==============================] - 3s 84ms/step - loss: 0.0032
# Epoch 74/100
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0035
# Epoch 75/100
# 30/30 [==============================] - 2s 79ms/step - loss: 0.0035
# Epoch 76/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0035
# Epoch 77/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0031
# Epoch 78/100
# 30/30 [==============================] - 2s 75ms/step - loss: 0.0033
# Epoch 79/100
# 30/30 [==============================] - 2s 74ms/step - loss: 0.0033
# Epoch 80/100
# 30/30 [==============================] - 2s 81ms/step - loss: 0.0035
# Epoch 81/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0031
# Epoch 82/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0035
# Epoch 83/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0034
# Epoch 84/100
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0033
# Epoch 85/100
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0031
# Epoch 86/100
# 30/30 [==============================] - 2s 73ms/step - loss: 0.0035
# Epoch 87/100
# 30/30 [==============================] - 2s 74ms/step - loss: 0.0034
# Epoch 88/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0032
# Epoch 89/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0034
# Epoch 90/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0028
# Epoch 91/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0031
# Epoch 92/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0032
# Epoch 93/100
# 30/30 [==============================] - 2s 73ms/step - loss: 0.0031
# Epoch 94/100
# 30/30 [==============================] - 2s 73ms/step - loss: 0.0029
# Epoch 95/100
# 30/30 [==============================] - 2s 73ms/step - loss: 0.0032
# Epoch 96/100
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0032
# Epoch 97/100
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0032
# Epoch 98/100
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0029
# Epoch 99/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0032
# Epoch 100/100
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0030

# %%
y_train = sc.inverse_transform(y_train)

y_train_predict = model.predict(x_train)

y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 30/30 [==============================] - 2s 27ms/step

# %%
test = df[len(train_data)-60:].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

x_test = []
for i in range(60, test.shape[0]):
    x_test.append(sc_test[i-60:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data[t:]

print('x_test shape == {}.'.format(x_test.shape))
print('y_test shape == {}.'.format(y_test.shape))
# Out:
# x_test shape == (249, 60, 1).
# y_test shape == (249, 1).

# %%
y_test_predict = model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict)
# Out:
# 8/8 [==============================] - 0s 20ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
mae = mean_absolute_error(y_test, y_test_predict)
mape = mean_absolute_percentage_error(y_test, y_test_predict)
mse = mean_squared_error(y_test, y_test_predict)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_test_predict)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 6475.65
# MAPE: 5.84%
# MSE: 57623254.73
# RMSE: 7591.00
# R2: 0.76

# %%
test_data1 = df[t:]

plt.figure(figsize=(20,10))
plt.plot(df[t:], label='Annual price', color='r')
test_data1['pred'] = y_test_predict
plt.plot(test_data1['pred'], label='Test predict Price', color='b')
plt.title('Compare Predict Price and Annual Price')
plt.xlabel('date')
plt.ylabel('Price OF MSN (VND)')
plt.legend()
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_23876\4170711069.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1['pred'] = y_test_predict

# %%
predictions_future = model.predict(x_test[-30:])
# Out:
# 1/1 [==============================] - 0s 41ms/step

# %%
predictions_future
# Out:
# array([[0.3530328 ],
#        [0.34855157],
#        [0.34450287],
#        [0.3408033 ],
#        [0.3381123 ],
#        [0.3377862 ],
#        [0.34032792],
#        [0.3458713 ],
#        [0.35415632],
#        [0.36329123],
#        [0.37310427],
#        [0.38285297],
#        [0.39201522],
#        [0.40054512],
#        [0.40852386],
#        [0.4144544 ],
#        [0.41913557],
#        [0.42352396],
#        [0.4280563 ],
#        [0.43317962],
#        [0.43991798],
#        [0.44817615],
#        [0.4575599 ],
#        [0.46671805],
#        [0.47511894],
#        [0.48139423],
#        [0.48633656],
#        [0.49108326],
#        [0.49644753],
#        [0.5031089 ]], dtype=float32)

# %%
predict = sc.inverse_transform(predictions_future)
predict
# Out:
# array([[76108.37 ],
#        [75649.99 ],
#        [75235.86 ],
#        [74857.43 ],
#        [74582.17 ],
#        [74548.81 ],
#        [74808.805],
#        [75375.83 ],
#        [76223.3  ],
#        [77157.695],
#        [78161.47 ],
#        [79158.65 ],
#        [80095.84 ],
#        [80968.36 ],
#        [81784.5  ],
#        [82391.125],
#        [82869.96 ],
#        [83318.84 ],
#        [83782.45 ],
#        [84306.516],
#        [84995.77 ],
#        [85840.49 ],
#        [86800.34 ],
#        [87737.125],
#        [88596.445],
#        [89238.336],
#        [89743.88 ],
#        [90229.42 ],
#        [90778.12 ],
#        [91459.51 ]], dtype=float32)

# %%
predict.shape
# Out:
# (30, 1)

# %%
datelist_future = pd.date_range(start="12/2/2022",end="12/31/2022")

# %%
new_date=df.index.append(datelist_future)
new_date
# Out:
# DatetimeIndex(['2017-12-01', '2017-12-04', '2017-12-05', '2017-12-06',
#                '2017-12-07', '2017-12-08', '2017-12-11', '2017-12-12',
#                '2017-12-13', '2017-12-14',
#                ...
#                '2022-12-22', '2022-12-23', '2022-12-24', '2022-12-25',
#                '2022-12-26', '2022-12-27', '2022-12-28', '2022-12-29',
#                '2022-12-30', '2022-12-31'],
#               dtype='datetime64[ns]', length=1279, freq=None)

# %%
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(df.index, df['Price'], 'red', label="Original data")
plt.plot(datelist_future, predict, 'orange', label="Prediction data")
plt.axvline(x = min(datelist_future), color='green', linewidth=2, linestyle='--')
plt.legend(loc='upper left')
plt.show()
