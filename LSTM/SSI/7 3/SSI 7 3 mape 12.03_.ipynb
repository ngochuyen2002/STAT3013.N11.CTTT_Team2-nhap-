# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv(r"E:\2022-2023 hk1\PTTK\CK\code\1-12-2017 1-12-2022\SSI Historical Data.csv")
df
# Out:
#             Date    Price     Open     High      Low        Vol.  Change %
# 0      12/1/2017  13928.5  13625.2  14105.5  13574.6  10420000.0      0.02
# 1      12/4/2017  14712.2  14054.9  14813.3  13979.1  11520000.0      0.06
# 2      12/5/2017  14257.2  14661.6  14712.2  14156.1  11100000.0     -0.03
# 3      12/6/2017  14130.8  14206.6  14257.2  13625.2  14660000.0     -0.01
# 4      12/7/2017  13701.0  14130.8  14156.1  13599.9   8850000.0     -0.03
# ...          ...      ...      ...      ...      ...         ...       ...
# 1244  11/25/2022  17100.0  16400.0  17100.0  16150.0  22570000.0      0.07
# 1245  11/28/2022  18250.0  17500.0  18250.0  17500.0  32640000.0      0.07
# 1246  11/29/2022  18950.0  18500.0  19150.0  18000.0  32280000.0      0.04
# 1247  11/30/2022  19250.0  18700.0  19400.0  18450.0  29650000.0      0.02
# 1248   12/1/2022  18200.0  19500.0  19650.0  18200.0  37110000.0     -0.05
#
# [1249 rows x 7 columns]

# %%
df['Date']=pd.to_datetime(df.Date,format='%m/%d/%Y')
df=df.set_index(pd.DatetimeIndex(df['Date'].values))

# %%
plt.figure(figsize=(20,10))
plt.plot(df['Price'])
plt.show()

# %%
df.index = df.Date
df = pd.DataFrame(df, columns=['Price'])

# %%
import math
data = df.values
t = math.ceil(len(df)* 0.7)
train_data = data[:t]
test_data = data[t:]

# %%
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)
sc_train
# Out:
# array([[0.17657386],
#        [0.19462959],
#        [0.18414681],
#        ...,
#        [0.29226463],
#        [0.29917635],
#        [0.27498531]])

# %%
x_train=[]
y_train=[]
for i in range(60, len(train_data)):
    x_train.append(sc_train[i-60:i, 0])
    y_train.append(sc_train[i, 0])
    
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

print('x_train shape == {}.'.format(x_train.shape))
print('y_train shape == {}.'.format(y_train.shape))
# Out:
# x_train shape == (815, 60, 1).
# y_train shape == (815, 1).

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2
import tensorflow as tf

learning_rate = 0.0001
hidden_unit = 64
batch_size = 32
epoch = 100
model = Sequential()
model.add(LSTM(units=hidden_unit, return_sequences=True, input_shape =(x_train.shape[1],1), activation="relu"))
model.add(Dropout(0.2))
model.add(LSTM(units=hidden_unit, return_sequences=True,activation="relu"))
model.add(Dropout(0.2))
model.add(LSTM(units=hidden_unit, return_sequences=False,activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),loss='mean_squared_error')
pred = model.fit(x_train, y_train ,batch_size=batch_size, epochs=epoch)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 5s 47ms/step - loss: 0.0302
# Epoch 2/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0161
# Epoch 3/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0053
# Epoch 4/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0041
# Epoch 5/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0027
# Epoch 6/100
# 26/26 [==============================] - 1s 52ms/step - loss: 0.0022
# Epoch 7/100
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0018
# Epoch 8/100
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0018
# Epoch 9/100
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0017
# Epoch 10/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0016
# Epoch 11/100
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0016
# Epoch 12/100
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0016
# Epoch 13/100
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0015
# Epoch 14/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0015
# Epoch 15/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0014
# Epoch 16/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0014
# Epoch 17/100
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0014
# Epoch 18/100
# 26/26 [==============================] - 1s 57ms/step - loss: 0.0015
# Epoch 19/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0015
# Epoch 20/100
# 26/26 [==============================] - 1s 54ms/step - loss: 0.0013
# Epoch 21/100
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0014
# Epoch 22/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0013
# Epoch 23/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0013
# Epoch 24/100
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0014
# Epoch 25/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0013
# Epoch 26/100
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0014
# Epoch 27/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0013
# Epoch 28/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0012
# Epoch 29/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0012
# Epoch 30/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0012
# Epoch 31/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0012
# Epoch 32/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0012
# Epoch 33/100
# 26/26 [==============================] - 1s 51ms/step - loss: 0.0011
# Epoch 34/100
# 26/26 [==============================] - 1s 51ms/step - loss: 0.0012
# Epoch 35/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0011
# Epoch 36/100
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0012
# Epoch 37/100
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0012
# Epoch 38/100
# 26/26 [==============================] - 2s 58ms/step - loss: 0.0011
# Epoch 39/100
# 26/26 [==============================] - 1s 51ms/step - loss: 0.0011
# Epoch 40/100
# 26/26 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 41/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0011
# Epoch 42/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0011
# Epoch 43/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0012
# Epoch 44/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0011
# Epoch 45/100
# 26/26 [==============================] - 1s 52ms/step - loss: 0.0011
# Epoch 46/100
# 26/26 [==============================] - 1s 54ms/step - loss: 0.0010
# Epoch 47/100
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0010
# Epoch 48/100
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0010
# Epoch 49/100
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0010
# Epoch 50/100
# 26/26 [==============================] - 1s 53ms/step - loss: 0.0010
# Epoch 51/100
# 26/26 [==============================] - 1s 48ms/step - loss: 9.7042e-04
# Epoch 52/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.
100
# 26/26 [==============================] - 1s 43ms/step - loss: 8.1904e-04
# Epoch 89/100
# 26/26 [==============================] - 1s 43ms/step - loss: 8.8509e-04
# Epoch 90/100
# 26/26 [==============================] - 1s 44ms/step - loss: 7.4532e-04
# Epoch 91/100
# 26/26 [==============================] - 1s 42ms/step - loss: 7.1829e-04
# Epoch 92/100
# 26/26 [==============================] - 1s 46ms/step - loss: 6.9894e-04
# Epoch 93/100
# 26/26 [==============================] - 1s 43ms/step - loss: 8.0284e-04
# Epoch 94/100
# 26/26 [==============================] - 1s 43ms/step - loss: 7.1415e-04
# Epoch 95/100
# 26/26 [==============================] - 1s 43ms/step - loss: 7.1925e-04
# Epoch 96/100
# 26/26 [==============================] - 1s 43ms/step - loss: 7.0474e-04
# Epoch 97/100
# 26/26 [==============================] - 1s 48ms/step - loss: 6.8761e-04
# Epoch 98/100
# 26/26 [==============================] - 1s 44ms/step - loss: 7.1969e-04
# Epoch 99/100
# 26/26 [==============================] - 1s 50ms/step - loss: 7.7983e-04
# Epoch 100/100
# 26/26 [==============================] - 1s 52ms/step - loss: 6.8621e-04

# %%
y_train = sc.inverse_transform(y_train)

y_train_predict = model.predict(x_train)

y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 26/26 [==============================] - 1s 21ms/step

# %%
test = df[len(train_data)-60:].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

x_test = []
for i in range(60, test.shape[0]):
    x_test.append(sc_test[i-60:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data[t:]

print('x_test shape == {}.'.format(x_test.shape))
print('y_test shape == {}.'.format(y_test.shape))
# Out:
# x_test shape == (374, 60, 1).
# y_test shape == (374, 1).

# %%
y_test_predict = model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict)
# Out:
# 12/12 [==============================] - 0s 13ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
mae = mean_absolute_error(y_test, y_test_predict)
mape = mean_absolute_percentage_error(y_test, y_test_predict)
mse = mean_squared_error(y_test, y_test_predict)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_test_predict)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 4090.88
# MAPE: 12.03%
# MSE: 31691097.33
# RMSE: 5629.48
# R2: 0.65

# %%
test_data1 = df[t:]

plt.figure(figsize=(20,10))
plt.plot(df[t:], label='Annual price', color='r')
test_data1['pred'] = y_test_predict
plt.plot(test_data1['pred'], label='Test predict Price', color='b')
plt.title('Compare Predict Price and Annual Price')
plt.xlabel('Date')
plt.ylabel('Price OF SSI (VND)')
plt.legend()
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_27544\1696953657.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1['pred'] = y_test_predict

# %%
predictions_future = model.predict(x_test[-30:])
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
predictions_future
# Out:
# array([[0.24984404],
#        [0.25052157],
#        [0.24982134],
#        [0.24732906],
#        [0.24300519],
#        [0.2377533 ],
#        [0.23230714],
#        [0.22745639],
#        [0.22403592],
#        [0.22210601],
#        [0.22156182],
#        [0.22149977],
#        [0.22079396],
#        [0.21937075],
#        [0.21724746],
#        [0.2140083 ],
#        [0.20978561],
#        [0.20494959],
#        [0.19967973],
#        [0.19482863],
#        [0.19148037],
#        [0.19033083],
#        [0.19143692],
#        [0.19465533],
#        [0.1992284 ],
#        [0.20460027],
#        [0.21089989],
#        [0.21860859],
#        [0.22802725],
#        [0.23905799]], dtype=float32)

# %%
predict = sc.inverse_transform(predictions_future)
predict
# Out:
# array([[17108.756],
#        [17138.164],
#        [17107.771],
#        [16999.594],
#        [16811.92 ],
#        [16583.963],
#        [16347.575],
#        [16137.031],
#        [15988.567],
#        [15904.801],
#        [15881.181],
#        [15878.487],
#        [15847.853],
#        [15786.078],
#        [15693.918],
#        [15553.324],
#        [15370.04 ],
#        [15160.135],
#        [14931.399],
#        [14720.84 ],
#        [14575.51 ],
#        [14525.615],
#        [14573.624],
#        [14713.317],
#        [14911.81 ],
#        [15144.973],
#        [15418.404],
#        [15752.997],
#        [16161.81 ],
#        [16640.594]], dtype=float32)

# %%
predict.shape
# Out:
# (30, 1)

# %%
datelist_future = pd.date_range(start="12/2/2022",end="12/31/2022")

# %%
new_date=df.index.append(datelist_future)
new_date
# Out:
# DatetimeIndex(['2017-12-01', '2017-12-04', '2017-12-05', '2017-12-06',
#                '2017-12-07', '2017-12-08', '2017-12-11', '2017-12-12',
#                '2017-12-13', '2017-12-14',
#                ...
#                '2022-12-22', '2022-12-23', '2022-12-24', '2022-12-25',
#                '2022-12-26', '2022-12-27', '2022-12-28', '2022-12-29',
#                '2022-12-30', '2022-12-31'],
#               dtype='datetime64[ns]', length=1279, freq=None)

# %%
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(df.index, df['Price'], 'red', label="Original data")
plt.plot(datelist_future, predict, 'orange', label="Prediction data")
plt.axvline(x = min(datelist_future), color='green', linewidth=2, linestyle='--')
plt.legend(loc='upper left')
plt.xlabel('Date')
plt.ylabel('Price OF SSI (VND)')
plt.show()
