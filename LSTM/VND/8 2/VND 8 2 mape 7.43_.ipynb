# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv(r"E:\2022-2023 hk1\PTTK\CK\code\1-12-2017 1-12-2022\VND Historical Data.csv")
df
# Out:
#             Date    Price     Open     High      Low        Vol.  Change %
# 0      12/1/2017  16511.9  16477.2  16615.9  16338.4   1060000.0      0.01
# 1      12/4/2017  16997.5  16720.0  17309.7  16615.9   1600000.0      0.03
# 2      12/5/2017  16303.7  16997.5  16997.5  16303.7   2360000.0     -0.04
# 3      12/6/2017  16234.4  16234.4  16373.1  15748.7   2620000.0      0.00
# 4      12/7/2017  15818.1  16303.7  16338.4  15679.3   1070000.0     -0.03
# ...          ...      ...      ...      ...      ...         ...       ...
# 1238  11/25/2022  11250.0  10850.0  11250.0  10700.0  23100000.0      0.07
# 1239  11/28/2022  12000.0  11700.0  12000.0  11600.0  34140000.0      0.07
# 1240  11/29/2022  12800.0  12400.0  12800.0  12050.0  47920000.0      0.07
# 1241  11/30/2022  13600.0  13000.0  13600.0  12550.0  36160000.0      0.06
# 1242   12/1/2022  13000.0  14050.0  14200.0  12900.0  46760000.0     -0.04
#
# [1243 rows x 7 columns]

# %%
df['Date']=pd.to_datetime(df.Date,format='%m/%d/%Y')
df=df.set_index(pd.DatetimeIndex(df['Date'].values))

# %%
plt.figure(figsize=(20,10))
plt.xlabel('Date')
plt.ylabel('Close Price (VND)')
plt.plot(df['Price'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a84a351fd06b> in <module>
# ----> 1 plt.figure(figsize=(20,10))
#       2 plt.xlabel('Date')
#       3 plt.ylabel('Close Price (VND)')
#       4 plt.plot(df['Price'])
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.index = df.Date
df = pd.DataFrame(df, columns=['Price'])

# %%
import math
data = df.values
t = math.ceil(len(df)* 0.8)
train_data = data[:t]
test_data = data[t:]

# %%
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)
sc_train
# Out:
# array([[0.43264517],
#        [0.44772296],
#        [0.42618059],
#        ...,
#        [0.31739132],
#        [0.34223118],
#        [0.32360128]])

# %%
x_train=[]
y_train=[]
for i in range(60, len(train_data)):
    x_train.append(sc_train[i-60:i, 0])
    y_train.append(sc_train[i, 0])
    
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

print('x_train shape == {}.'.format(x_train.shape))
print('y_train shape == {}.'.format(y_train.shape))
# Out:
# x_train shape == (935, 60, 1).
# y_train shape == (935, 1).

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2
import tensorflow as tf

learning_rate = 0.0001
hidden_unit = 64
batch_size = 32
epoch = 100
model = Sequential()
model.add(LSTM(units=hidden_unit, return_sequences=True, input_shape =(x_train.shape[1],1), activation="relu"))
model.add(Dropout(0.2))
model.add(LSTM(units=hidden_unit, return_sequences=True,activation="relu"))
model.add(Dropout(0.2))
model.add(LSTM(units=hidden_unit, return_sequences=False,activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),loss='mean_squared_error')
pred = model.fit(x_train, y_train ,batch_size=batch_size, epochs=epoch)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 14s 84ms/step - loss: 0.1308
# Epoch 2/100
# 30/30 [==============================] - 2s 80ms/step - loss: 0.0910
# Epoch 3/100
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0294
# Epoch 4/100
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0130
# Epoch 5/100
# 30/30 [==============================] - 2s 61ms/step - loss: 0.0103
# Epoch 6/100
# 30/30 [==============================] - 2s 60ms/step - loss: 0.0099
# Epoch 7/100
# 30/30 [==============================] - 2s 76ms/step - loss: 0.0086
# Epoch 8/100
# 30/30 [==============================] - 2s 78ms/step - loss: 0.0075
# Epoch 9/100
# 30/30 [==============================] - 2s 73ms/step - loss: 0.0071
# Epoch 10/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0072
# Epoch 11/100
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0060
# Epoch 12/100
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0061
# Epoch 13/100
# 30/30 [==============================] - 2s 76ms/step - loss: 0.0063
# Epoch 14/100
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0062
# Epoch 15/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0057
# Epoch 16/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0052
# Epoch 17/100
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0058
# Epoch 18/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0056
# Epoch 19/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0047
# Epoch 20/100
# 30/30 [==============================] - 3s 87ms/step - loss: 0.0045
# Epoch 21/100
# 30/30 [==============================] - 2s 76ms/step - loss: 0.0045
# Epoch 22/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0046
# Epoch 23/100
# 30/30 [==============================] - 2s 79ms/step - loss: 0.0045
# Epoch 24/100
# 30/30 [==============================] - 2s 77ms/step - loss: 0.0040
# Epoch 25/100
# 30/30 [==============================] - 2s 76ms/step - loss: 0.0044
# Epoch 26/100
# 30/30 [==============================] - 2s 78ms/step - loss: 0.0041
# Epoch 27/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0040
# Epoch 28/100
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0043
# Epoch 29/100
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0039
# Epoch 30/100
# 30/30 [==============================] - 2s 73ms/step - loss: 0.0040
# Epoch 31/100
# 30/30 [==============================] - 2s 76ms/step - loss: 0.0039
# Epoch 32/100
# 30/30 [==============================] - 3s 85ms/step - loss: 0.0041
# Epoch 33/100
# 30/30 [==============================] - 2s 73ms/step - loss: 0.0039
# Epoch 34/100
# 30/30 [==============================] - 2s 78ms/step - loss: 0.0036
# Epoch 35/100
# 30/30 [==============================] - 3s 84ms/step - loss: 0.0039
# Epoch 36/100
# 30/30 [==============================] - 3s 86ms/step - loss: 0.0035
# Epoch 37/100
# 30/30 [==============================] - 2s 80ms/step - loss: 0.0034
# Epoch 38/100
# 30/30 [==============================] - 3s 88ms/step - loss: 0.0030
# Epoch 39/100
# 30/30 [==============================] - 3s 83ms/step - loss: 0.0035
# Epoch 40/100
# 30/30 [==============================] - 3s 91ms/step - loss: 0.0031
# Epoch 41/100
# 30/30 [==============================] - 3s 94ms/step - loss: 0.0037
# Epoch 42/100
# 30/30 [==============================] - 3s 97ms/step - loss: 0.0036
# Epoch 43/100
# 30/30 [==============================] - 3s 102ms/step - loss: 0.0037
# Epoch 44/100
# 30/30 [==============================] - 3s 104ms/step - loss: 0.0034
# Epoch 45/100
# 30/30 [==============================] - 3s 116ms/step - loss: 0.0036
# Epoch 46/100
# 30/30 [==============================] - 4s 116ms/step - loss: 0.0032
# Epoch 47/100
# 30/30 [==============================] - 3s 104ms/step - loss: 0.0033
# Epoch 48/100
# 30/30 [==============================] - 3s 113ms/step - loss: 0.0036
# Epoch 49/100
# 30/30 [==============================] - 3s 108ms/step - loss: 0.0030
# Epoch 50/100
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0028
# Epoch 51/100
# 30/30 [==============================] - 3s 100ms/step - loss: 0.0030
# Epoch 52/100
# 30/30 [==============================] - 3s 97ms/step - loss: 0.0031
# Epoch 53/100
# 30/30 [==============================] - 3s 90ms/step - loss: 0.0032
# Epoch 54/100
# 30/30 [==============================] - 3s 88ms/step - loss: 0.0028
# Epoch 55/100
# 30/30 [==============================] - 3s 84ms/step - loss: 0.0032
# Epoch 56/100
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0032
# Epoch 57/100
# 30/30 [==============================] - 3s 85ms/step - loss: 0.0027
# Epoch 58/100
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0026
# Epoch 59/100
# 30/30 [==============================] - 2s 76ms/step - loss: 0.0034
# Epoch 60/100
# 30/30 [==============================] - 2s 76ms/step - loss: 0.0031
# Epoch 61/100
# 30/30 [==============================] - 2s 79ms/step - loss: 0.0029
# Epoch 62/100
# 30/30 [==============================] - 2s 77ms/step - loss: 0.0028
# Epoch 63/100
# 30/30 [==============================] - 2s 79ms/step - loss: 0.0030
# Epoch 64/100
# 30/30 [==============================] - 3s 84ms/step - loss: 0.0029
# Epoch 65/100
# 30/30 [==============================] - 3s 90ms/step - loss: 0.0030
# Epoch 66/100
# 30/30 [==============================] - 3s 95ms/step - loss: 0.0032
# Epoch 67/100
# 30/30 [==============================] - 3s 98ms/step - loss: 0.0029
# Epoch 68/100
# 30/30 [==============================] - 3s 96ms/step - loss: 0.0031
# Epoch 69/100
# 30/30 [==============================] - 3s 95ms/step - loss: 0.0027
# Epoch 70/100
# 30/30 [==============================] - 3s 97ms/step - loss: 0.0031
# Epoch 71/100
# 30/30 [==============================] - 3s 97ms/step - loss: 0.0031
# Epoch 72/100
# 30/30 [==============================] - 3s 97ms/step - loss: 0.0028
# Epoch 73/100
# 30/30 [==============================] - 3s 96ms/step - loss: 0.0030
# Epoch 74/100
# 30/30 [==============================] - 3s 104ms/step - loss: 0.0027
# Epoch 75/100
# 30/30 [==============================] - 3s 93ms/step - loss: 0.0030
# Epoch 76/100
# 30/30 [==============================] - 3s 95ms/step - loss: 0.0027
# Epoch 77/100
# 30/30 [==============================] - 3s 91ms/step - loss: 0.0030
# Epoch 78/100
# 30/30 [==============================] - 3s 89ms/step - loss: 0.0029
# Epoch 79/100
# 30/30 [==============================] - 3s 88ms/step - loss: 0.0028
# Epoch 80/100
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0028
# Epoch 81/100
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0027
# Epoch 82/100
# 30/30 [==============================] - 3s 96ms/step - loss: 0.0026
# Epoch 83/100
# 30/30 [==============================] - 3s 93ms/step - loss: 0.0026
# Epoch 84/100
# 30/30 [==============================] - 3s 94ms/step - loss: 0.0032
# Epoch 85/100
# 30/30 [==============================] - 3s 106ms/step - loss: 0.0029
# Epoch 86/100
# 30/30 [==============================] - 3s 96ms/step - loss: 0.0025
# Epoch 87/100
# 30/30 [==============================] - 3s 97ms/step - loss: 0.0026
# Epoch 88/100
# 30/30 [==============================] - 3s 99ms/step - loss: 0.0026
# Epoch 89/100
# 30/30 [==============================] - 3s 98ms/step - loss: 0.0028
# Epoch 90/100
# 30/30 [==============================] - 3s 91ms/step - loss: 0.0025
# Epoch 91/100
# 30/30 [==============================] - 3s 102ms/step - loss: 0.0029
# Epoch 92/100
# 30/30 [==============================] - 3s 93ms/step - loss: 0.0028
# Epoch 93/100
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0022
# Epoch 94/100
# 30/30 [==============================] - 3s 96ms/step - loss: 0.0027
# Epoch 95/100
# 30/30 [==============================] - 3s 106ms/step - loss: 0.0025
# Epoch 96/100
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0027
# Epoch 97/100
# 30/30 [==============================] - 3s 108ms/step - loss: 0.0029
# Epoch 98/100
# 30/30 [==============================] - 3s 105ms/step - loss: 0.0023
# Epoch 99/100
# 30/30 [==============================] - 3s 97ms/step - loss: 0.0024
# Epoch 100/100
# 30/30 [==============================] - 3s 109ms/step - loss: 0.0025

# %%
y_train = sc.inverse_transform(y_train)

y_train_predict = model.predict(x_train)

y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 30/30 [==============================] - 6s 30ms/step

# %%
test = df[len(train_data)-60:].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

x_test = []
for i in range(60, test.shape[0]):
    x_test.append(sc_test[i-60:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data[t:]

print('x_test shape == {}.'.format(x_test.shape))
print('y_test shape == {}.'.format(y_test.shape))
# Out:
# x_test shape == (248, 60, 1).
# y_test shape == (248, 1).

# %%
y_test_predict = model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict)
# Out:
# 8/8 [==============================] - 0s 29ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
mae = mean_absolute_error(y_test, y_test_predict)
mape = mean_absolute_percentage_error(y_test, y_test_predict)
mse = mean_squared_error(y_test, y_test_predict)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_test_predict)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 1649.65
# MAPE: 7.43%
# MSE: 4658948.88
# RMSE: 2158.46
# R2: 0.91

# %%
test_data1 = df[t:]

plt.figure(figsize=(20,10))
plt.plot(df[t:], label='Annual price', color='r')
test_data1['pred'] = y_test_predict
plt.plot(test_data1['pred'], label='Test predict Price', color='b')
plt.title('Compare Predict Price and Annual Price')
plt.xlabel('Date')
plt.ylabel('Price OF VND (VND)')
plt.legend()
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_30640\1696953657.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1['pred'] = y_test_predict

# %%
predictions_future = model.predict(x_test[-30:])
# Out:
# 1/1 [==============================] - 0s 141ms/step

# %%
predictions_future
# Out:
# array([[0.35724357],
#        [0.35579002],
#        [0.35365057],
#        [0.3495616 ],
#        [0.3425499 ],
#        [0.33341044],
#        [0.32333004],
#        [0.313118  ],
#        [0.30371082],
#        [0.29593033],
#        [0.2900424 ],
#        [0.285514  ],
#        [0.28145406],
#        [0.2776299 ],
#        [0.2738151 ],
#        [0.26938692],
#        [0.2643251 ],
#        [0.25924012],
#        [0.25420526],
#        [0.24987908],
#        [0.24699838],
#        [0.24581605],
#        [0.24643739],
#        [0.24868123],
#        [0.25167182],
#        [0.25478187],
#        [0.2581382 ],
#        [0.26224297],
#        [0.26772183],
#        [0.2751219 ]], dtype=float32)

# %%
predict = sc.inverse_transform(predictions_future)
predict
# Out:
# array([[14083.493],
#        [14036.68 ],
#        [13967.776],
#        [13836.086],
#        [13610.265],
#        [13315.917],
#        [12991.265],
#        [12662.372],
#        [12359.401],
#        [12108.82 ],
#        [11919.192],
#        [11773.35 ],
#        [11642.594],
#        [11519.432],
#        [11396.571],
#        [11253.956],
#        [11090.934],
#        [10927.165],
#        [10765.011],
#        [10625.681],
#        [10532.904],
#        [10494.825],
#        [10514.837],
#        [10587.103],
#        [10683.418],
#        [10783.581],
#        [10891.677],
#        [11023.876],
#        [11200.329],
#        [11438.658]], dtype=float32)

# %%
predict.shape
# Out:
# (30, 1)

# %%
datelist_future = pd.date_range(start="12/2/2022",end="12/31/2022")

# %%
new_date=df.index.append(datelist_future)
new_date
# Out:
# DatetimeIndex(['2017-12-01', '2017-12-04', '2017-12-05', '2017-12-06',
#                '2017-12-07', '2017-12-08', '2017-12-11', '2017-12-12',
#                '2017-12-13', '2017-12-14',
#                ...
#                '2022-12-22', '2022-12-23', '2022-12-24', '2022-12-25',
#                '2022-12-26', '2022-12-27', '2022-12-28', '2022-12-29',
#                '2022-12-30', '2022-12-31'],
#               dtype='datetime64[ns]', length=1273, freq=None)

# %%
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(df.index, df['Price'], 'red', label="Original data")
plt.plot(datelist_future, predict, 'orange', label="Prediction data")
plt.axvline(x = min(datelist_future), color='green', linewidth=2, linestyle='--')
plt.legend(loc='upper left')
plt.xlabel('Date')
plt.ylabel('Price OF VND (VND)')
plt.show()
