# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv(r"E:\2022-2023 hk1\PTTK\CK\code\1-12-2017 1-12-2022\VND Historical Data.csv")
df
# Out:
#             Date    Price     Open     High      Low        Vol.  Change %
# 0      12/1/2017  16511.9  16477.2  16615.9  16338.4   1060000.0      0.01
# 1      12/4/2017  16997.5  16720.0  17309.7  16615.9   1600000.0      0.03
# 2      12/5/2017  16303.7  16997.5  16997.5  16303.7   2360000.0     -0.04
# 3      12/6/2017  16234.4  16234.4  16373.1  15748.7   2620000.0      0.00
# 4      12/7/2017  15818.1  16303.7  16338.4  15679.3   1070000.0     -0.03
# ...          ...      ...      ...      ...      ...         ...       ...
# 1238  11/25/2022  11250.0  10850.0  11250.0  10700.0  23100000.0      0.07
# 1239  11/28/2022  12000.0  11700.0  12000.0  11600.0  34140000.0      0.07
# 1240  11/29/2022  12800.0  12400.0  12800.0  12050.0  47920000.0      0.07
# 1241  11/30/2022  13600.0  13000.0  13600.0  12550.0  36160000.0      0.06
# 1242   12/1/2022  13000.0  14050.0  14200.0  12900.0  46760000.0     -0.04
#
# [1243 rows x 7 columns]

# %%
df['Date']=pd.to_datetime(df.Date,format='%m/%d/%Y')
df=df.set_index(pd.DatetimeIndex(df['Date'].values))

# %%
plt.figure(figsize=(20,10))
plt.plot(df['Price'])
plt.show()

# %%
# Set the index of the DataFrame to the 'date' column
df.index = df.Date
df = pd.DataFrame(df, columns=['Price'])

# %%
import math
data = df.values
t = math.ceil(len(df)* 0.9)
train_data = data[:t]
test_data = data[t:]

# %%
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)
sc_train
# Out:
# array([[0.43264517],
#        [0.44772296],
#        [0.42618059],
#        ...,
#        [0.31739132],
#        [0.34223118],
#        [0.32360128]])

# %%
x_train=[]
y_train=[]
for i in range(60, len(train_data)):
    x_train.append(sc_train[i-60:i, 0])
    y_train.append(sc_train[i, 0])
    
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

print('x_train shape == {}.'.format(x_train.shape))
print('y_train shape == {}.'.format(y_train.shape))
# Out:
# x_train shape == (1059, 60, 1).
# y_train shape == (1059, 1).

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2
import tensorflow as tf

learning_rate = 0.0001
hidden_unit = 64
batch_size = 32
epoch = 100
model = Sequential()
model.add(LSTM(units=hidden_unit, return_sequences=True, input_shape =(x_train.shape[1],1), activation="relu"))
model.add(Dropout(0.2))
model.add(LSTM(units=hidden_unit, return_sequences=True,activation="relu"))
model.add(Dropout(0.2))
model.add(LSTM(units=hidden_unit, return_sequences=False,activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),loss='mean_squared_error')
pred = model.fit(x_train, y_train ,batch_size=batch_size, epochs=epoch)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 5s 43ms/step - loss: 0.1871
# Epoch 2/100
# 34/34 [==============================] - 1s 43ms/step - loss: 0.1089
# Epoch 3/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0207
# Epoch 4/100
# 34/34 [==============================] - 1s 43ms/step - loss: 0.0117
# Epoch 5/100
# 34/34 [==============================] - 1s 42ms/step - loss: 0.0089
# Epoch 6/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0088
# Epoch 7/100
# 34/34 [==============================] - 1s 42ms/step - loss: 0.0078
# Epoch 8/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0072
# Epoch 9/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0075
# Epoch 10/100
# 34/34 [==============================] - 1s 43ms/step - loss: 0.0068
# Epoch 11/100
# 34/34 [==============================] - 1s 44ms/step - loss: 0.0068
# Epoch 12/100
# 34/34 [==============================] - 1s 43ms/step - loss: 0.0058
# Epoch 13/100
# 34/34 [==============================] - 1s 43ms/step - loss: 0.0056
# Epoch 14/100
# 34/34 [==============================] - 1s 43ms/step - loss: 0.0060
# Epoch 15/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0062
# Epoch 16/100
# 34/34 [==============================] - 1s 44ms/step - loss: 0.0055
# Epoch 17/100
# 34/34 [==============================] - 1s 44ms/step - loss: 0.0055
# Epoch 18/100
# 34/34 [==============================] - 1s 44ms/step - loss: 0.0053
# Epoch 19/100
# 34/34 [==============================] - 2s 49ms/step - loss: 0.0054
# Epoch 20/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0053
# Epoch 21/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0052
# Epoch 22/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0053
# Epoch 23/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0045
# Epoch 24/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0047
# Epoch 25/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0050
# Epoch 26/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0048
# Epoch 27/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0047
# Epoch 28/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0044
# Epoch 29/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0048
# Epoch 30/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0051
# Epoch 31/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0043
# Epoch 32/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0044
# Epoch 33/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0044
# Epoch 34/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0045
# Epoch 35/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0044
# Epoch 36/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0042
# Epoch 37/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0039
# Epoch 38/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0039
# Epoch 39/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0041
# Epoch 40/100
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0045
# Epoch 41/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0045
# Epoch 42/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0042
# Epoch 43/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0042
# Epoch 44/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0041
# Epoch 45/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0043
# Epoch 46/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0039
# Epoch 47/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0042
# Epoch 48/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0040
# Epoch 49/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0040
# Epoch 50/100
# 34/34 [==============================] - 2s 49ms/step - loss: 0.0037
# Epoch 51/100
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0036
# Epoch 52/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0041
# Epoch 53/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0039
# Epoch 54/100
# 34/34 [==============================] - 2s 48ms/step - loss: 0.0037
# Epoch 55/100
# 34/34 [==============================] - 2s 48ms/step - loss: 0.0038
# Epoch 56/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0037
# Epoch 57/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0037
# Epoch 58/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0036
# Epoch 59/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0041
# Epoch 60/100
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0038
# Epoch 61/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0034
# Epoch 62/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0036
# Epoch 63/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0039
# Epoch 64/100
# 34/34 [==============================] - 2s 48ms/step - loss: 0.0033
# Epoch 65/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0038
# Epoch 66/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0035
# Epoch 67/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0037
# Epoch 68/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0032
# Epoch 69/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0039
# Epoch 70/100
# 34/34 [==============================] - 2s 50ms/step - loss: 0.0033
# Epoch 71/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0036
# Epoch 72/100
# 34/34 [==============================] - 2s 49ms/step - loss: 0.0034
# Epoch 73/100
# 34/34 [==============================] - 2s 49ms/step - loss: 0.0035
# Epoch 74/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0035
# Epoch 75/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0032
# Epoch 76/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0035
# Epoch 77/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0035
# Epoch 78/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0037
# Epoch 79/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0034
# Epoch 80/100
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0032
# Epoch 81/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0036
# Epoch 82/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0032
# Epoch 83/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0033
# Epoch 84/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0035
# Epoch 85/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0032
# Epoch 86/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0037
# Epoch 87/100
# 34/34 [==============================] - 2s 49ms/step - loss: 0.0030
# Epoch 88/100
# 34/34 [==============================] - 2s 50ms/step - loss: 0.0040
# Epoch 89/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0035
# Epoch 90/100
# 34/34 [==============================] - 2s 50ms/step - loss: 0.0030
# Epoch 91/100
# 34/34 [==============================] - 2s 47ms/step - loss: 0.0032
# Epoch 92/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0034
# Epoch 93/100
# 34/34 [==============================] - 2s 45ms/step - loss: 0.0034
# Epoch 94/100
# 34/34 [==============================] - 2s 46ms/step - loss: 0.0034
# Epoch 95/100
# 34/34 [==============================] - 2s 48ms/step - loss: 0.0029
# Epoch 96/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0032
# Epoch 97/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0032
# Epoch 98/100
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0030
# Epoch 99/100
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0031
# Epoch 100/100
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0033

# %%
y_train = sc.inverse_transform(y_train)

y_train_predict = model.predict(x_train)

y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 34/34 [==============================] - 1s 16ms/step

# %%
test = df[len(train_data)-60:].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

x_test = []
for i in range(60, test.shape[0]):
    x_test.append(sc_test[i-60:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data[t:]

print('x_test shape == {}.'.format(x_test.shape))
print('y_test shape == {}.'.format(y_test.shape))
# Out:
# x_test shape == (124, 60, 1).
# y_test shape == (124, 1).

# %%
y_test_predict = model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict)
# Out:
# 4/4 [==============================] - 0s 18ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
mae = mean_absolute_error(y_test, y_test_predict)
mape = mean_absolute_percentage_error(y_test, y_test_predict)
mse = mean_squared_error(y_test, y_test_predict)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_test_predict)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 1237.38
# MAPE: 7.64%
# MSE: 3142291.41
# RMSE: 1772.65
# R2: 0.81

# %%
test_data1 = df[t:]
plt.figure(figsize=(20,10))
plt.plot(df[t:], label='Annual price', color='r')
test_data1['pred'] = y_test_predict
plt.plot(test_data1['pred'], label='Test predict Price', color='b')
plt.title('Compare Predict Price and Annual Price')
plt.xlabel('Date')
plt.ylabel('Price OF VND (VND)')
plt.legend()
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_13000\2610456308.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1['pred'] = y_test_predict

# %%
predictions_future = model.predict(x_test[-30:])
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
predictions_future
# Out:
# array([[0.35013467],
#        [0.34936574],
#        [0.34775212],
#        [0.3437886 ],
#        [0.33630973],
#        [0.3262259 ],
#        [0.3149396 ],
#        [0.30339664],
#        [0.2928022 ],
#        [0.28422964],
#        [0.27808437],
#        [0.27373338],
#        [0.27012172],
#        [0.2668794 ],
#        [0.2636771 ],
#        [0.25974038],
#        [0.25496802],
#        [0.2500085 ],
#        [0.24500145],
#        [0.24072845],
#        [0.23808008],
#        [0.23732658],
#        [0.23852162],
#        [0.24140753],
#        [0.24500827],
#        [0.2485721 ],
#        [0.25217566],
#        [0.25634572],
#        [0.26181993],
#        [0.26931626]], dtype=float32)

# %%
predict = sc.inverse_transform(predictions_future)
predict
# Out:
# array([[13854.542],
#        [13829.777],
#        [13777.809],
#        [13650.158],
#        [13409.292],
#        [13084.529],
#        [12721.039],
#        [12349.283],
#        [12008.076],
#        [11731.984],
#        [11534.068],
#        [11393.939],
#        [11277.621],
#        [11173.198],
#        [11070.063],
#        [10943.276],
#        [10789.576],
#        [10629.849],
#        [10468.591],
#        [10330.973],
#        [10245.679],
#        [10221.411],
#        [10259.899],
#        [10352.844],
#        [10468.811],
#        [10583.588],
#        [10699.645],
#        [10833.947],
#        [11010.251],
#        [11251.68 ]], dtype=float32)

# %%
predict.shape
# Out:
# (30, 1)

# %%
datelist_future = pd.date_range(start="12/2/2022",end="12/31/2022")

# %%
new_date=df.index.append(datelist_future)
new_date
# Out:
# DatetimeIndex(['2017-12-01', '2017-12-04', '2017-12-05', '2017-12-06',
#                '2017-12-07', '2017-12-08', '2017-12-11', '2017-12-12',
#                '2017-12-13', '2017-12-14',
#                ...
#                '2022-12-22', '2022-12-23', '2022-12-24', '2022-12-25',
#                '2022-12-26', '2022-12-27', '2022-12-28', '2022-12-29',
#                '2022-12-30', '2022-12-31'],
#               dtype='datetime64[ns]', length=1273, freq=None)

# %%
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(df.index, df['Price'], 'red', label="Original data")
plt.plot(datelist_future, predict, 'orange', label="Prediction data")
plt.axvline(x = min(datelist_future), color='green', linewidth=2, linestyle='--')
plt.legend(loc='upper left')
plt.xlabel('Date')
plt.ylabel('Price OF VND (VND)')
plt.show()
