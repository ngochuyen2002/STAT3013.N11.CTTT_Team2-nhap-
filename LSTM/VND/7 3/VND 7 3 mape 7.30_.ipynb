# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv(r"E:\2022-2023 hk1\PTTK\CK\code\1-12-2017 1-12-2022\VND Historical Data.csv")
df
# Out:
#             Date    Price     Open     High      Low        Vol.  Change %
# 0      12/1/2017  16511.9  16477.2  16615.9  16338.4   1060000.0      0.01
# 1      12/4/2017  16997.5  16720.0  17309.7  16615.9   1600000.0      0.03
# 2      12/5/2017  16303.7  16997.5  16997.5  16303.7   2360000.0     -0.04
# 3      12/6/2017  16234.4  16234.4  16373.1  15748.7   2620000.0      0.00
# 4      12/7/2017  15818.1  16303.7  16338.4  15679.3   1070000.0     -0.03
# ...          ...      ...      ...      ...      ...         ...       ...
# 1238  11/25/2022  11250.0  10850.0  11250.0  10700.0  23100000.0      0.07
# 1239  11/28/2022  12000.0  11700.0  12000.0  11600.0  34140000.0      0.07
# 1240  11/29/2022  12800.0  12400.0  12800.0  12050.0  47920000.0      0.07
# 1241  11/30/2022  13600.0  13000.0  13600.0  12550.0  36160000.0      0.06
# 1242   12/1/2022  13000.0  14050.0  14200.0  12900.0  46760000.0     -0.04
#
# [1243 rows x 7 columns]

# %%
df['Date']=pd.to_datetime(df.Date,format='%m/%d/%Y')
df=df.set_index(pd.DatetimeIndex(df['Date'].values))

# %%
plt.figure(figsize=(20,10))
plt.plot(df['Price'])
plt.show()

# %%
# Set the index of the DataFrame to the 'date' column
df.index = df.Date
df = pd.DataFrame(df, columns=['Price'])

# %%
import math
data = df.values
t = math.ceil(len(df)* 0.7)
train_data = data[:t]
test_data = data[t:]

# %%
sc = MinMaxScaler(feature_range=(0, 1))
sc_train = sc.fit_transform(data)
sc_train
# Out:
# array([[0.43264517],
#        [0.44772296],
#        [0.42618059],
#        ...,
#        [0.31739132],
#        [0.34223118],
#        [0.32360128]])

# %%
x_train=[]
y_train=[]
for i in range(60, len(train_data)):
    x_train.append(sc_train[i-60:i, 0])
    y_train.append(sc_train[i, 0])
    
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

print('x_train shape == {}.'.format(x_train.shape))
print('y_train shape == {}.'.format(y_train.shape))
# Out:
# x_train shape == (811, 60, 1).
# y_train shape == (811, 1).

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2
import tensorflow as tf

learning_rate = 0.0001
hidden_unit = 64
batch_size = 32
epoch = 100
model = Sequential()
model.add(LSTM(units=hidden_unit, return_sequences=True, input_shape =(x_train.shape[1],1), activation="relu"))
model.add(Dropout(0.2))
model.add(LSTM(units=hidden_unit, return_sequences=True,activation="relu"))
model.add(Dropout(0.2))
model.add(LSTM(units=hidden_unit, return_sequences=False,activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),loss='mean_squared_error')
pred = model.fit(x_train, y_train ,batch_size=batch_size, epochs=epoch)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 5s 45ms/step - loss: 0.0980
# Epoch 2/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0692
# Epoch 3/100
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0291
# Epoch 4/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0098
# Epoch 5/100
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0065
# Epoch 6/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0051
# Epoch 7/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0058
# Epoch 8/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0057
# Epoch 9/100
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0043
# Epoch 10/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0042
# Epoch 11/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0048
# Epoch 12/100
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0048
# Epoch 13/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0040
# Epoch 14/100
# 26/26 [==============================] - 1s 55ms/step - loss: 0.0039
# Epoch 15/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0041
# Epoch 16/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0040
# Epoch 17/100
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0036
# Epoch 18/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0040
# Epoch 19/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0037
# Epoch 20/100
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0040
# Epoch 21/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0041
# Epoch 22/100
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0036
# Epoch 23/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0034
# Epoch 24/100
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0033
# Epoch 25/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0035
# Epoch 26/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0035
# Epoch 27/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0031
# Epoch 28/100
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0032
# Epoch 29/100
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0029
# Epoch 30/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0036
# Epoch 31/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0031
# Epoch 32/100
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0031
# Epoch 33/100
# 26/26 [==============================] - 1s 51ms/step - loss: 0.0030
# Epoch 34/100
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0032
# Epoch 35/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0028
# Epoch 36/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0028
# Epoch 37/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0028
# Epoch 38/100
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0031
# Epoch 39/100
# 26/26 [==============================] - 1s 54ms/step - loss: 0.0030
# Epoch 40/100
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0031
# Epoch 41/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0028
# Epoch 42/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0029
# Epoch 43/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0025
# Epoch 44/100
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0025
# Epoch 45/100
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0023
# Epoch 46/100
# 26/26 [==============================] - 1s 54ms/step - loss: 0.0026
# Epoch 47/100
# 26/26 [==============================] - 1s 53ms/step - loss: 0.0028
# Epoch 48/100
# 26/26 [==============================] - 1s 52ms/step - loss: 0.0028
# Epoch 49/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0028
# Epoch 50/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0027
# Epoch 51/100
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0028
# Epoch 52/100
# 26/26 [==============================] - 1s 52ms/step - loss: 0.0029
# Epoch 53/100
# 26/26 [==============================] - 1s 56ms/step - loss: 0.0027
# Epoch 54/100
# 26/26 [==============================] - 1s 52ms/step - loss: 0.0026
# Epoch 55/100
# 26/26 [==============================] - 1s 45ms/step - loss: 0.0025
# Epoch 56/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0028
# Epoch 57/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0027
# Epoch 58/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0023
# Epoch 59/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0027
# Epoch 60/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0025
# Epoch 61/100
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0025
# Epoch 62/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0025
# Epoch 63/100
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0024
# Epoch 64/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0027
# Epoch 65/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0026
# Epoch 66/100
# 26/26 [==============================] - 1s 52ms/step - loss: 0.0025
# Epoch 67/100
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0023
# Epoch 68/100
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0025
# Epoch 69/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0025
# Epoch 70/100
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0025
# Epoch 71/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0025
# Epoch 72/100
# 26/26 [==============================] - 1s 54ms/step - loss: 0.0028
# Epoch 73/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0022
# Epoch 74/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0025
# Epoch 75/100
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0023
# Epoch 76/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0019
# Epoch 77/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0025
# Epoch 78/100
# 26/26 [==============================] - 1s 57ms/step - loss: 0.0026
# Epoch 79/100
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0024
# Epoch 80/100
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0024
# Epoch 81/100
# 26/26 [==============================] - 1s 52ms/step - loss: 0.0026
# Epoch 82/100
# 26/26 [==============================] - 1s 54ms/step - loss: 0.0024
# Epoch 83/100
# 26/26 [==============================] - 1s 51ms/step - loss: 0.0022
# Epoch 84/100
# 26/26 [==============================] - 2s 69ms/step - loss: 0.0026
# Epoch 85/100
# 26/26 [==============================] - 2s 68ms/step - loss: 0.0026
# Epoch 86/100
# 26/26 [==============================] - 2s 75ms/step - loss: 0.0026
# Epoch 87/100
# 26/26 [==============================] - 2s 76ms/step - loss: 0.0024
# Epoch 88/100
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0025
# Epoch 89/100
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0027
# Epoch 90/100
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0022
# Epoch 91/100
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0023
# Epoch 92/100
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0027
# Epoch 93/100
# 26/26 [==============================] - 1s 51ms/step - loss: 0.0024
# Epoch 94/100
# 26/26 [==============================] - 2s 60ms/step - loss: 0.0025
# Epoch 95/100
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0025
# Epoch 96/100
# 26/26 [==============================] - 1s 55ms/step - loss: 0.0023
# Epoch 97/100
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0025
# Epoch 98/100
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0023
# Epoch 99/100
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0022
# Epoch 100/100
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0025

# %%
y_train = sc.inverse_transform(y_train)

y_train_predict = model.predict(x_train)

y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 26/26 [==============================] - 1s 15ms/step

# %%
test = df[len(train_data)-60:].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

x_test = []
for i in range(60, test.shape[0]):
    x_test.append(sc_test[i-60:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data[t:]

print('x_test shape == {}.'.format(x_test.shape))
print('y_test shape == {}.'.format(y_test.shape))
# Out:
# x_test shape == (372, 60, 1).
# y_test shape == (372, 1).

# %%
y_test_predict = model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict)
# Out:
# 12/12 [==============================] - 0s 13ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
mae = mean_absolute_error(y_test, y_test_predict)
mape = mean_absolute_percentage_error(y_test, y_test_predict)
mse = mean_squared_error(y_test, y_test_predict)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_test_predict)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 1598.85
# MAPE: 7.30%
# MSE: 4221694.56
# RMSE: 2054.68
# R2: 0.90

# %%
test_data1 = df[t:]
plt.figure(figsize=(20,10))
plt.plot(df[t:], label='Annual price', color='r')
test_data1['pred'] = y_test_predict
plt.plot(test_data1['pred'], label='Test predict Price', color='b')
plt.title('Compare Predict Price and Annual Price')
plt.xlabel('Date')
plt.ylabel('Price OF SSI (VND)')
plt.legend()
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_11328\2204084320.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1['pred'] = y_test_predict

# %%
predictions_future = model.predict(x_test[-30:])
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
predictions_future
# Out:
# array([[0.34137234],
#        [0.33922666],
#        [0.33663568],
#        [0.33242425],
#        [0.32564515],
#        [0.3169633 ],
#        [0.3073358 ],
#        [0.29750997],
#        [0.28836796],
#        [0.28069097],
#        [0.2747515 ],
#        [0.27006125],
#        [0.26579955],
#        [0.26175955],
#        [0.25774655],
#        [0.25323367],
#        [0.24820367],
#        [0.24322212],
#        [0.2383529 ],
#        [0.23420742],
#        [0.23147815],
#        [0.23039755],
#        [0.23100975],
#        [0.23317122],
#        [0.2360889 ],
#        [0.23918003],
#        [0.24254927],
#        [0.24666068],
#        [0.2520631 ],
#        [0.2592548 ]], dtype=float32)

# %%
predict = sc.inverse_transform(predictions_future)
predict
# Out:
# array([[13572.34  ],
#        [13503.235 ],
#        [13419.789 ],
#        [13284.155 ],
#        [13065.825 ],
#        [12786.215 ],
#        [12476.148 ],
#        [12159.695 ],
#        [11865.265 ],
#        [11618.018 ],
#        [11426.7295],
#        [11275.674 ],
#        [11138.42  ],
#        [11008.307 ],
#        [10879.0625],
#        [10733.72  ],
#        [10571.722 ],
#        [10411.284 ],
#        [10254.465 ],
#        [10120.954 ],
#        [10033.055 ],
#        [ 9998.253 ],
#        [10017.969 ],
#        [10087.582 ],
#        [10181.55  ],
#        [10281.104 ],
#        [10389.614 ],
#        [10522.027 ],
#        [10696.02  ],
#        [10927.638 ]], dtype=float32)

# %%
predict.shape
# Out:
# (30, 1)

# %%
datelist_future = pd.date_range(start="12/2/2022",end="12/31/2022")

# %%
new_date=df.index.append(datelist_future)
new_date
# Out:
# DatetimeIndex(['2017-12-01', '2017-12-04', '2017-12-05', '2017-12-06',
#                '2017-12-07', '2017-12-08', '2017-12-11', '2017-12-12',
#                '2017-12-13', '2017-12-14',
#                ...
#                '2022-12-22', '2022-12-23', '2022-12-24', '2022-12-25',
#                '2022-12-26', '2022-12-27', '2022-12-28', '2022-12-29',
#                '2022-12-30', '2022-12-31'],
#               dtype='datetime64[ns]', length=1273, freq=None)

# %%
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(df.index, df['Price'], 'red', label="Original data")
plt.plot(datelist_future, predict, 'orange', label="Prediction data")
plt.axvline(x = min(datelist_future), color='green', linewidth=2, linestyle='--')
plt.legend(loc='upper left')
plt.xlabel('Date')
plt.ylabel('Price OF SSI (VND)')
plt.show()
