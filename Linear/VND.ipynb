# %%
import numpy.polynomial.polynomial as poly
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
VND=pd.read_csv(r"E:\2022-2023 hk1\PTTK\CK\code\1-12-2017 1-12-2022\VND Historical Data.csv")

# %%
VND
# Out:
#             Date    Price     Open     High      Low        Vol.  Change %
# 0      12/1/2017  16511.9  16477.2  16615.9  16338.4   1060000.0      0.01
# 1      12/4/2017  16997.5  16720.0  17309.7  16615.9   1600000.0      0.03
# 2      12/5/2017  16303.7  16997.5  16997.5  16303.7   2360000.0     -0.04
# 3      12/6/2017  16234.4  16234.4  16373.1  15748.7   2620000.0      0.00
# 4      12/7/2017  15818.1  16303.7  16338.4  15679.3   1070000.0     -0.03
# ...          ...      ...      ...      ...      ...         ...       ...
# 1238  11/25/2022  11250.0  10850.0  11250.0  10700.0  23100000.0      0.07
# 1239  11/28/2022  12000.0  11700.0  12000.0  11600.0  34140000.0      0.07
# 1240  11/29/2022  12800.0  12400.0  12800.0  12050.0  47920000.0      0.07
# 1241  11/30/2022  13600.0  13000.0  13600.0  12550.0  36160000.0      0.06
# 1242   12/1/2022  13000.0  14050.0  14200.0  12900.0  46760000.0     -0.04
#
# [1243 rows x 7 columns]

# %%
VND['Time'] = np.arange(len(VND.index))

# %%
VND
# Out:
#            Date    Price     Open     High      Low    Vol.  Change %  Time
# 0      6/1/2020   3132.1   3096.0   3132.1   3083.9   2.22M      0.02     0
# 1      6/2/2020   3108.0   3168.2   3168.2   3071.9   2.79M     -0.01     1
# 2      6/3/2020   3120.1   3132.1   3132.1   3083.9   1.18M      0.00     2
# 3      6/4/2020   3276.7   3168.2   3312.8   3168.2   6.94M      0.05     3
# 4      6/5/2020   3312.8   3252.6   3336.9   3228.5   2.18M      0.01     4
# ..          ...      ...      ...      ...      ...     ...       ...   ...
# 620  11/25/2022  11250.0  10850.0  11250.0  10700.0  23.10M      0.07   620
# 621  11/28/2022  12000.0  11700.0  12000.0  11600.0  34.14M      0.07   621
# 622  11/29/2022  12800.0  12400.0  12800.0  12050.0  47.92M      0.07   622
# 623  11/30/2022  13600.0  13000.0  13600.0  12550.0  36.16M      0.06   623
# 624   12/1/2022  13000.0  14050.0  14200.0  12900.0  46.76M     -0.04   624
#
# [625 rows x 8 columns]

# %%
VND['Date_New'] = pd.to_datetime(VND.Date)

# %%
type(VND['Date_New'])
# Out:
# pandas.core.series.Series

# %%
VND.index = VND['Date_New']

# %%
VND.index
# Out:
# DatetimeIndex(['2020-06-01', '2020-06-02', '2020-06-03', '2020-06-04',
#                '2020-06-05', '2020-06-08', '2020-06-09', '2020-06-10',
#                '2020-06-11', '2020-06-12',
#                ...
#                '2022-11-18', '2022-11-21', '2022-11-22', '2022-11-23',
#                '2022-11-24', '2022-11-25', '2022-11-28', '2022-11-29',
#                '2022-11-30', '2022-12-01'],
#               dtype='datetime64[ns]', name='Date_New', length=625, freq=None)

# %%
VND['Price'].plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Date_New'>

# %%
VND.index
# Out:
# DatetimeIndex(['2020-06-01', '2020-06-02', '2020-06-03', '2020-06-04',
#                '2020-06-05', '2020-06-08', '2020-06-09', '2020-06-10',
#                '2020-06-11', '2020-06-12',
#                ...
#                '2022-11-18', '2022-11-21', '2022-11-22', '2022-11-23',
#                '2022-11-24', '2022-11-25', '2022-11-28', '2022-11-29',
#                '2022-11-30', '2022-12-01'],
#               dtype='datetime64[ns]', name='Date_New', length=625, freq=None)

# %%
x = np.array(VND.Time, dtype = float)
y = np.array(VND.Price, dtype = float)
z = [625,626,627,628,629,630,631,632,633,634,635,636,637,638,639,640,641,642,643,644,645,646,647,648,649,650,651,652,653,654]

# %%
no_of_predictions=30
datelist_future = pd.date_range(start="12/2/2022",end="12/31/2022")

# %%
coefs = poly.polyfit(x, y,1)
x_new = np.linspace(x[0], x[-1] + no_of_predictions, num = len(x) + no_of_predictions)
ffit = poly.polyval(x_new, coefs)
pred = poly.polyval(z, coefs)
predictions = pd.DataFrame(datelist_future,pred)
print (predictions)
# Out:
#                       0
# 27620.078566 2022-12-02
# 27658.392419 2022-12-03
# 27696.706271 2022-12-04
# 27735.020124 2022-12-05
# 27773.333976 2022-12-06
# 27811.647829 2022-12-07
# 27849.961681 2022-12-08
# 27888.275534 2022-12-09
# 27926.589387 2022-12-10
# 27964.903239 2022-12-11
# 28003.217092 2022-12-12
# 28041.530944 2022-12-13
# 28079.844797 2022-12-14
# 28118.158649 2022-12-15
# 28156.472502 2022-12-16
# 28194.786354 2022-12-17
# 28233.100207 2022-12-18
# 28271.414059 2022-12-19
# 28309.727912 2022-12-20
# 28348.041764 2022-12-21
# 28386.355617 2022-12-22
# 28424.669470 2022-12-23
# 28462.983322 2022-12-24
# 28501.297175 2022-12-25
# 28539.611027 2022-12-26
# 28577.924880 2022-12-27
# 28616.238732 2022-12-28
# 28654.552585 2022-12-29
# 28692.866437 2022-12-30
# 28731.180290 2022-12-31

# %%
new_date=VND.index.append(datelist_future)
new_date
# Out:
# DatetimeIndex(['2020-06-01', '2020-06-02', '2020-06-03', '2020-06-04',
#                '2020-06-05', '2020-06-08', '2020-06-09', '2020-06-10',
#                '2020-06-11', '2020-06-12',
#                ...
#                '2022-12-22', '2022-12-23', '2022-12-24', '2022-12-25',
#                '2022-12-26', '2022-12-27', '2022-12-28', '2022-12-29',
#                '2022-12-30', '2022-12-31'],
#               dtype='datetime64[ns]', length=655, freq=None)

# %%
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(VND.index, y, 'red', label="Original data")
plt.plot(new_date, ffit, label = "Fitted data")
plt.plot(datelist_future, pred, 'orange', label="Prediction data")
plt.axvline(x = min(datelist_future), color='green', linewidth=2, linestyle='--')
plt.legend(loc='upper left')
plt.show()
