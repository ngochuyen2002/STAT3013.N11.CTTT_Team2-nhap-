# %%
import numpy.polynomial.polynomial as poly
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
MSN=pd.read_csv(r"E:\2022-2023 hk1\PTTK\CK\code\1-12-2017 1-12-2022\MSN Historical Data.csv")

# %%
MSN
# Out:
#             Date     Price      Open      High      Low       Vol.  Change %
# 0      12/1/2017   68500.0   67000.0   69400.0  66500.0   725370.0      0.02
# 1      12/4/2017   69000.0   70000.0   70000.0  68800.0  1190000.0      0.01
# 2      12/5/2017   68900.0   69000.0   70100.0  68600.0   777070.0      0.00
# 3      12/6/2017   67700.0   68900.0   69000.0  66000.0  1080000.0     -0.02
# 4      12/7/2017   69000.0   68600.0   69800.0  67300.0  1560000.0      0.02
# ...          ...       ...       ...       ...      ...        ...       ...
# 1244  11/25/2022   94000.0   90000.0   94500.0  90000.0   923100.0      0.06
# 1245  11/28/2022   97200.0   94000.0   97200.0  93500.0  2130000.0      0.03
# 1246  11/29/2022   99000.0   97200.0   99000.0  95500.0  2170000.0      0.02
# 1247  11/30/2022  102000.0   99500.0  102000.0  92900.0  1500000.0      0.03
# 1248   12/1/2022   99000.0  102000.0  102000.0  99000.0  1540000.0     -0.03
#
# [1249 rows x 7 columns]

# %%
MSN['Time'] = np.arange(len(MSN.index))

# %%
MSN
# Out:
#             Date     Price      Open      High      Low       Vol.  Change %  \
# 0      12/1/2017   68500.0   67000.0   69400.0  66500.0   725370.0      0.02
# 1      12/4/2017   69000.0   70000.0   70000.0  68800.0  1190000.0      0.01
# 2      12/5/2017   68900.0   69000.0   70100.0  68600.0   777070.0      0.00
# 3      12/6/2017   67700.0   68900.0   69000.0  66000.0  1080000.0     -0.02
# 4      12/7/2017   69000.0   68600.0   69800.0  67300.0  1560000.0      0.02
# ...          ...       ...       ...       ...      ...        ...       ...
# 1244  11/25/2022   94000.0   90000.0   94500.0  90000.0   923100.0      0.06
# 1245  11/28/2022   97200.0   94000.0   97200.0  93500.0  2130000.0      0.03
# 1246  11/29/2022   99000.0   97200.0   99000.0  95500.0  2170000.0      0.02
# 1247  11/30/2022  102000.0   99500.0  102000.0  92900.0  1500000.0      0.03
# 1248   12/1/2022   99000.0  102000.0  102000.0  99000.0  1540000.0     -0.03
#
#       Time
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ...    ...
# 1244  1244
# 1245  1245
# 1246  1246
# 1247  1247
# 1248  1248
#
# [1249 rows x 8 columns]

# %%
MSN['Date_New'] = pd.to_datetime(MSN.Date)

# %%
type(MSN['Date_New'])
# Out:
# pandas.core.series.Series

# %%
MSN.index = MSN['Date_New']

# %%
MSN
# Out:
#                   Date     Price      Open      High      Low       Vol.  \
# Date_New
# 2017-12-01   12/1/2017   68500.0   67000.0   69400.0  66500.0   725370.0
# 2017-12-04   12/4/2017   69000.0   70000.0   70000.0  68800.0  1190000.0
# 2017-12-05   12/5/2017   68900.0   69000.0   70100.0  68600.0   777070.0
# 2017-12-06   12/6/2017   67700.0   68900.0   69000.0  66000.0  1080000.0
# 2017-12-07   12/7/2017   69000.0   68600.0   69800.0  67300.0  1560000.0
# ...                ...       ...       ...       ...      ...        ...
# 2022-11-25  11/25/2022   94000.0   90000.0   94500.0  90000.0   923100.0
# 2022-11-28  11/28/2022   97200.0   94000.0   97200.0  93500.0  2130000.0
# 2022-11-29  11/29/2022   99000.0   97200.0   99000.0  95500.0  2170000.0
# 2022-11-30  11/30/2022  102000.0   99500.0  102000.0  92900.0  1500000.0
# 2022-12-01   12/1/2022   99000.0  102000.0  102000.0  99000.0  1540000.0
#
#             Change %  Time   Date_New
# Date_New
# 2017-12-01      0.02     0 2017-12-01
# 2017-12-04      0.01     1 2017-12-04
# 2017-12-05      0.00     2 2017-12-05
# 2017-12-06     -0.02     3 2017-12-06
# 2017-12-07      0.02     4 2017-12-07
# ...              ...   ...        ...
# 2022-11-25      0.06  1244 2022-11-25
# 2022-11-28      0.03  1245 2022-11-28
# 2022-11-29      0.02  1246 2022-11-29
# 2022-11-30      0.03  1247 2022-11-30
# 2022-12-01     -0.03  1248 2022-12-01
#
# [1249 rows x 9 columns]

# %%
MSN['Price'].plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Date_New'>

# %%
MSN.index
# Out:
# DatetimeIndex(['2017-12-01', '2017-12-04', '2017-12-05', '2017-12-06',
#                '2017-12-07', '2017-12-08', '2017-12-11', '2017-12-12',
#                '2017-12-13', '2017-12-14',
#                ...
#                '2022-11-18', '2022-11-21', '2022-11-22', '2022-11-23',
#                '2022-11-24', '2022-11-25', '2022-11-28', '2022-11-29',
#                '2022-11-30', '2022-12-01'],
#               dtype='datetime64[ns]', name='Date_New', length=1249, freq=None)

# %%
no_of_predictions=30
datelist_future = pd.date_range(start="12/2/2022",end="12/31/2022")

# %%
x = np.array(MSN.Time, dtype = float)
y = np.array(MSN.Price, dtype = float)
z = [1249,1250,1251,1252,1253,1254,1255,1256,1257,1258,1259,1260,1261,1262,1263,1264,1265,1266,1267,1268,1269,1270,1271,1272,1273,1274,1275,1276,1277,1278]

# %%
coefs = poly.polyfit(x, y,8)
x_new = np.linspace(x[0], x[-1] + no_of_predictions, num = len(x) + no_of_predictions)
ffit = poly.polyval(x_new, coefs)
pred = poly.polyval(z, coefs)
predictions = pd.DataFrame(datelist_future,pred)
print (predictions)
# Out:
#                       0
# 84376.989620 2022-12-02
# 84038.761858 2022-12-03
# 83697.148431 2022-12-04
# 83352.063531 2022-12-05
# 83003.419559 2022-12-06
# 82651.127094 2022-12-07
# 82295.094882 2022-12-08
# 81935.229804 2022-12-09
# 81571.436862 2022-12-10
# 81203.619157 2022-12-11
# 80831.677861 2022-12-12
# 80455.512201 2022-12-13
# 80075.019437 2022-12-14
# 79690.094833 2022-12-15
# 79300.631644 2022-12-16
# 78906.521085 2022-12-17
# 78507.652315 2022-12-18
# 78103.912409 2022-12-19
# 77695.186336 2022-12-20
# 77281.356940 2022-12-21
# 76862.304910 2022-12-22
# 76437.908762 2022-12-23
# 76008.044813 2022-12-24
# 75572.587157 2022-12-25
# 75131.407640 2022-12-26
# 74684.375840 2022-12-27
# 74231.359039 2022-12-28
# 73772.222197 2022-12-29
# 73306.827934 2022-12-30
# 72835.036497 2022-12-31

# %%
new_date=MSN.index.append(datelist_future)
new_date
# Out:
# DatetimeIndex(['2017-12-01', '2017-12-04', '2017-12-05', '2017-12-06',
#                '2017-12-07', '2017-12-08', '2017-12-11', '2017-12-12',
#                '2017-12-13', '2017-12-14',
#                ...
#                '2022-12-22', '2022-12-23', '2022-12-24', '2022-12-25',
#                '2022-12-26', '2022-12-27', '2022-12-28', '2022-12-29',
#                '2022-12-30', '2022-12-31'],
#               dtype='datetime64[ns]', length=1279, freq=None)

# %%
plt.rcParams['figure.figsize'] = [20, 10]
plt.plot(MSN.index, y, 'red', label="Original data")
plt.plot(new_date, ffit, label = "Fitted data")
plt.plot(datelist_future, pred, 'orange', label="Prediction data")
plt.axvline(x = min(datelist_future), color='green', linewidth=2, linestyle='--')
plt.legend(loc='upper left')
plt.show()
